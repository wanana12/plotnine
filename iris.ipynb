# %% [markdown]
# <a href="https://colab.research.google.com/github/wanana12/plotnine/blob/main/iris.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## ライブラリの読み込み

# %%
import pandas as pd
from plotnine import *

# %% [markdown]
# ## データの読み込み

# %%
from sklearn.datasets import load_iris
iris = load_iris()
data = pd.DataFrame(data = iris.data, columns = iris.feature_names)
data.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
data['target'] = iris.target
data.loc[data['target'] == 0, 'target'] = "setosa"
data.loc[data['target'] == 1, 'target'] = "versicolor"
data.loc[data['target'] == 2, 'target'] = "virginica"
data.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0  setosa
# 1  setosa
# 2  setosa
# 3  setosa
# 4  setosa

# %% [markdown]
# ## データの可視化

# %%
(ggplot(data, aes(x = 'target', fill = 'target'))
 + geom_bar())
# Out:
# <Figure Size: (640 x 480)>

# %%
(ggplot(data, aes(x = 'sepal length (cm)', y = 'sepal width (cm)', color = 'target'))
 + geom_point())
# Out:
# <Figure Size: (640 x 480)>

# %%
(ggplot(data, aes(x = 'sepal length (cm)', fill = 'target'))
 + geom_histogram(position = "identity", alpha = 0.5, bins = 10))
# Out:
# <Figure Size: (640 x 480)>

# %%
(ggplot(data, aes(x = 'sepal length (cm)', fill = 'target'))
 + geom_density(alpha = 0.5))
# Out:
# <Figure Size: (640 x 480)>

# %%
(ggplot(data, aes(x = 'target', y = 'sepal length (cm)', fill = 'target'))
 + geom_boxplot())
# Out:
# <Figure Size: (640 x 480)>

# %%
(ggplot(data, aes(x = 'target', y = 'sepal length (cm)', fill = 'target'))
 + geom_violin())
# Out:
# <Figure Size: (640 x 480)>

# %%
(ggplot(data, aes(x = 'sepal length (cm)', y = 'sepal width (cm)', color = 'target'))
 + geom_point()
 + stat_density_2d())
# Out:
# <Figure Size: (640 x 480)>
